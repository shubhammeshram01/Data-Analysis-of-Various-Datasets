# %% [markdown]
# # Car Data Analysis :

# %% [markdown]
# > The data of different cars is given with their specification

# %% [markdown]
# ### 1)  Import libaries and dataset :

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as py
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\All Csv's\Cars data.csv")

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
data.shape
# Out:
# (432, 15)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=432, step=1)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
data.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
data.nunique()
# Out:
# Make            38
# Model          425
# Type             6
# Origin           3
# DriveTrain       3
# MSRP           410
# Invoice        425
# EngineSize      43
# Cylinders        7
# Horsepower     110
# MPG_City        28
# MPG_Highway     33
# Weight         348
# Wheelbase       40
# Length          67
# dtype: int64

# %%
data.isna().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
data.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %% [markdown]
# ### 2) Check null values and fill null values in cylinders with mean

# %%
data["Cylinders"].isna().sum()
# Out:
# 6

# %%
data["Cylinders"].fillna(data["Cylinders"].mean())
# Out:
# 0      6.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 427    5.0
# 428    5.0
# 429    6.0
# 430    4.0
# 431    5.0
# Name: Cylinders, Length: 432, dtype: float64

# %% [markdown]
# ### 3) Check what are the different types of Make are in dataset and what is the count of Make in dataset ?

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
data["Make"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', nan, 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
data["Make"].nunique()
# Out:
# 38

# %%
data["Make"].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# ### 4) Show all the records where Origin is Asia or Europe.

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
data[ (data["Origin"] == "Asia") | (data["Origin"] == "Europe")]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data [data["Origin"].isin(["Asia","Europe"])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### 5) Remove all the records (rows) where Weight is above 4000.

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
data[data["Weight"] > 4000]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
data[~(data["Weight"] > 4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### 6) Increase all the values of "MPG_City" column by 3.

# %%
data.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
data["MPG_City"].apply(lambda x : x+ 3)
# Out:
# 0      20.0
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 432, dtype: float64

# %%
data["MPG_City"] = data["MPG_City"].apply(lambda x : x+ 3)
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      20.0         23.0  4451.0
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %% [markdown]
# # Census 2011 Data Analysis :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\All Csv's\Census 2011.csv")

# %%
data.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
data.tail()
# Out:
#      District_code                   State_name              District_name  \
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# 635       41816   19143   22673     36470    11802          9093
# 636      200222   97809  102413    154916    68301         53139
# 637       36842   20727   16115     25332    17125         12714
# 638      105597   54861   50736     78683    38579         30612
# 639      238142  127283  110859    190266    96831         77563
#
#      Female_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# ...

# %%
data.shape
# Out:
# (640, 25)

# %%
data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=640, step=1)

# %%
data.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
data.count()
# Out:
# District_code           640
# State_name              640
# District_name           640
# Population              640
# Male                    640
# Female                  640
# Literate                640
# Workers                 640
# Male_Workers            640
# Female_Workers          640
# Cultivator_Workers      640
# Agricultural_Workers    640
# Household_Workers       640
# Hindus                  640
# Muslims                 640
# Christians              640
# Sikhs                   640
# Buddhists               640
# Jains                   640
# Secondary_Education     640
# Higher_Education        640
# Graduate_Education      640
# Age_Group_0_29          640
# Age_Group_30_49         640
# Age_Group_50            640
# dtype: int64

# %%
data.nunique()
# Out:
# District_code           640
# State_name               35
# District_name           634
# Population              640
# Male                    640
# Female                  640
# Literate                640
# Workers                 640
# Male_Workers            640
# Female_Workers          640
# Cultivator_Workers      639
# Agricultural_Workers    640
# Household_Workers       632
# Hindus                  640
# Muslims                 639
# Christians              622
# Sikhs                   565
# Buddhists               511
# Jains                   546
# Secondary_Education     640
# Higher_Education        640
# Graduate_Education      637
# Age_Group_0_29          640
# Age_Group_30_49         640
# Age_Group_50            639
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
data.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %% [markdown]
# ### 1) Show the records related to - New Delhi, Lucknow, Jaipur

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data [data["District_name"].isin(["New Delhi" , "Lucknow" , "Jaipur"])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ### 2) Calculate state wise
# * 1) State wise total population
# * 2) Total number of population with different religion state wise

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data.groupby("State_name")["Population"].sum().sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
data.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
data.groupby("State_name")['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum()
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# DAMAN AND DIU                   220150     19277        2820       172
# GOA                             963877    121564      366130      1473
# GUJARAT                       53533988   5846761      316178     58246
# HARYANA                       22171128   1781342       50353   1243752
# ...

# %% [markdown]
# ### 3) How many male workers in Maharashtra ?

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data[data["State_name"] == "MAHARASHTRA"]["Male_Workers"]
# Out:
# 496     442898
# 497     570448
# 498    1186472
# 499     734024
# 500     520362
# 501     340353
# 502     837577
# 503     392316
# 504    1334211
# 505     345054
# 506     383151
# 507     323338
# 508     648565
# 509     815475
# 510     925232
# 511     330903
# 512     501422
# 513     545030
# 514    1015864
# 515    1746286
# 516    3363123
# 517    2944322
# 518    1021009
# 519     753843
# 520    2809816
# 521    1300309
# 522     727819
# 523     670018
# 524     473795
# 525    1206933
# 526     844805
# 527     407008
# 528     229676
# 529    1125204
# 530     800214
# Name: Male_Workers, dtype: int64

# %%
data[data["State_name"] == "MAHARASHTRA"]['Male_Workers'].sum()
# Out:
# 32616875

# %%
df = data[data["State_name"] == "MAHARASHTRA"]
df
# Out:
#      District_code   State_name    District_name  Population     Male  \
# 496            497  MAHARASHTRA        Nandurbar     1648295   833170
# 497            498  MAHARASHTRA            Dhule     2050862  1054031
# 498            499  MAHARASHTRA          Jalgaon     4229917  2197365
# 499            500  MAHARASHTRA          Buldana     2586258  1337560
# 500            501  MAHARASHTRA            Akola     1813906   932334
# 501            502  MAHARASHTRA           Washim     1197160   620302
# 502            503  MAHARASHTRA         Amravati     2888445  1480768
# 503            504  MAHARASHTRA           Wardha     1300774   668385
# 504            505  MAHARASHTRA           Nagpur     4653570  2384975
# 505            506  MAHARASHTRA         Bhandara     1200334   605520
# 506            507  MAHARASHTRA          Gondiya     1322507   661554
# 507            508  MAHARASHTRA       Gadchiroli     1072942   541328
# ...

# %%
df.groupby("State_name")["Male_Workers"].sum()
# Out:
# State_name
# MAHARASHTRA    32616875
# Name: Male_Workers, dtype: int64

# %% [markdown]
# ### 4) Set first column as Index of Dataframe

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data.set_index("District_code")
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# ### 5) Add suffix and prefix to the columns

# %%
data.head(2)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
# 1         47      6                66459             41367
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
# 1               27950          503223           160933         88978
#
# [2 rows x 25 columns]

# %%
data.add_suffix("_Right")
# Out:
#      District_code_Right             State_name_Right  \
# 0                      1            JAMMU AND KASHMIR
# 1                      2            JAMMU AND KASHMIR
# 2                      3            JAMMU AND KASHMIR
# 3                      4            JAMMU AND KASHMIR
# 4                      5            JAMMU AND KASHMIR
# ..                   ...                          ...
# 635                  636                  PONDICHERRY
# 636                  637                  PONDICHERRY
# 637                  638  ANDAMAN AND NICOBAR ISLANDS
# 638                  639  ANDAMAN AND NICOBAR ISLANDS
# 639                  640  ANDAMAN AND NICOBAR ISLANDS
#
#            District_name_Right  Population_Right  Male_Right  Female_Right  \
# 0                      Kupwara            870354      474190        396164
# 1                       Badgam            753745      398041        355704
# 2                  Leh(Ladakh)            133487       78971         54516
# ...

# %%
data.add_prefix("Left_")
# Out:
#      Left_District_code              Left_State_name  \
# 0                     1            JAMMU AND KASHMIR
# 1                     2            JAMMU AND KASHMIR
# 2                     3            JAMMU AND KASHMIR
# 3                     4            JAMMU AND KASHMIR
# 4                     5            JAMMU AND KASHMIR
# ..                  ...                          ...
# 635                 636                  PONDICHERRY
# 636                 637                  PONDICHERRY
# 637                 638  ANDAMAN AND NICOBAR ISLANDS
# 638                 639  ANDAMAN AND NICOBAR ISLANDS
# 639                 640  ANDAMAN AND NICOBAR ISLANDS
#
#             Left_District_name  Left_Population  Left_Male  Left_Female  \
# 0                      Kupwara           870354     474190       396164
# 1                       Badgam           753745     398041       355704
# 2                  Leh(Ladakh)           133487      78971        54516
# ...

# %% [markdown]
# # Covid 19 Data Analysis :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\All Csv's\Covid 19 data.csv")

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data.shape
# Out:
# (321, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
data.dtypes
# Out:
# Date         object
# State        object
# Region       object
# Confirmed     int64
# Deaths        int64
# Recovered     int64
# dtype: object

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.nunique()
# Out:
# Date           1
# State        137
# Region       187
# Confirmed    282
# Deaths       142
# Recovered    195
# dtype: int64

# %%
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
sns.heatmap(data.isna())
py.show()

# %%
data.isna().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# ### 1) Show the number of Confirmed, Deaths and Recovered cases in each region

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby("Region")[["Confirmed" , "Deaths" , "Recovered"]].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby("Region").sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# ### 2) Remove all the records where Confirmed Cases is Less Than 10

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[~(data["Confirmed"] < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# ### 3) In which region maximum number of Confirmed Cases were recorded ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby("Region")["Confirmed"].sum().sort_values(ascending = False).head(5)
# Out:
# Region
# US        1039909
# Spain      236899
# Italy      203591
# France     166543
# UK         166441
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### 4) In which region , minimum number of deaths recorded ?

# %%
data.groupby("Region")["Deaths"].sum().sort_values(ascending=True).head(5)
# Out:
# Region
# Laos          0
# Mongolia      0
# Mozambique    0
# Cambodia      0
# Fiji          0
# Name: Deaths, dtype: int64

# %% [markdown]
# ### 5) How many Confirmed, Deaths, and Recovered cases were reported from India till 29 April 2020 ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data['Region'] == "India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# ### 6) Sort the entire data wrt no. of Confirmed Cases in ascending order

# %%
data["Confirmed"].sort_values()
# Out:
# 285         0
# 284         0
# 203         0
# 305         1
# 289         1
#         ...
# 57     165093
# 168    165221
# 80     203591
# 153    236899
# 265    299691
# Name: Confirmed, Length: 321, dtype: int64

# %%
data.sort_values(by = "Confirmed" , ascending = True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %% [markdown]
# ### 7) Sort entire data wrt no. of recovered cases

# %%
data.sort_values(by = "Recovered" , ascending = True)
# Out:
#           Date                 State   Region  Confirmed  Deaths  Recovered
# 240  4/29/2020                Kansas       US       3839     134          0
# 279  4/29/2020  Prince Edward Island   Canada         27       0          0
# 251  4/29/2020              Michigan       US      40399    3670          0
# 193  4/29/2020      British Columbia   Canada       2087     109          0
# 280  4/29/2020           Puerto Rico       US       1433      86          0
# ..         ...                   ...      ...        ...     ...        ...
# 80   4/29/2020                   NaN    Italy     203591   27682      71252
# 76   4/29/2020                   NaN     Iran      93657    5957      73791
# 61   4/29/2020                   NaN  Germany     161539    6467     120400
# 285  4/29/2020             Recovered       US          0       0     120720
# 153  4/29/2020                   NaN    Spain     236899   24275     132929
#
# [321 rows x 6 columns]

# %% [markdown]
# # London Housing Data Analysis :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\All Csv's\Housing data.csv")

# %%
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.tail()
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13544   9/1/2019  england         249942  E92000001      64605.0           NaN
# 13545  10/1/2019  england         249376  E92000001      68677.0           NaN
# 13546  11/1/2019  england         248515  E92000001      67814.0           NaN
# 13547  12/1/2019  england         250410  E92000001          NaN           NaN
# 13548   1/1/2020  england         247355  E92000001          NaN           NaN

# %%
data.index
# Out:
# RangeIndex(start=0, stop=13549, step=1)

# %%
data.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
data.shape
# Out:
# (13549, 6)

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.isna().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 635.2+ KB

# %%
data.nunique()
# Out:
# date               301
# area                45
# average_price    13343
# code                45
# houses_sold       3946
# no_of_crimes      2669
# dtype: int64

# %%
data.describe()
# Out:
#        average_price    houses_sold  no_of_crimes
# count   1.354900e+04   13455.000000   7439.000000
# mean    2.635197e+05    3893.994129   2158.352063
# std     1.876175e+05   12114.402476    902.087742
# min     4.072200e+04       2.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000
# 50%     2.229190e+05     371.000000   2132.000000
# 75%     3.368430e+05    3146.000000   2582.000000
# max     1.463378e+06  132163.000000   7461.000000

# %%
sns.heatmap(data.isna())
py.show()

# %% [markdown]
# ### 1) Convert the datatype of "Date" column to "Data-Time" format

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data["date"]
# Out:
# 0         1/1/1995
# 1         2/1/1995
# 2         3/1/1995
# 3         4/1/1995
# 4         5/1/1995
#            ...
# 13544     9/1/2019
# 13545    10/1/2019
# 13546    11/1/2019
# 13547    12/1/2019
# 13548     1/1/2020
# Name: date, Length: 13549, dtype: object

# %%
data["date"] = pd.to_datetime(data["date"])
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# ### 2) Add a new columns "day","month","year" in the dataframe

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data["day"] = data["date"].dt.day
data["month"] = data["date"].dt.month
data["year"] = data["date"].dt.year


data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  day  month  year
# 0               NaN    1      1  1995
# ...

# %% [markdown]
# ### 3) Add column "day_name" as 2nd column in dataframe , which contains day_name only.

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  day  month  year
# 0           NaN    1      1  1995
# 1           NaN    1      2  1995

# %%
data.insert(2 , "day_name" , data["date"].dt.day_name() )

data
# Out:
#             date            area   day_name  average_price       code  \
# 0     1995-01-01  city of london     Sunday          91449  E09000001
# 1     1995-02-01  city of london  Wednesday          82203  E09000001
# 2     1995-03-01  city of london  Wednesday          79121  E09000001
# 3     1995-04-01  city of london   Saturday          77101  E09000001
# 4     1995-05-01  city of london     Monday          84409  E09000001
# ...          ...             ...        ...            ...        ...
# 13544 2019-09-01         england     Sunday         249942  E92000001
# 13545 2019-10-01         england    Tuesday         249376  E92000001
# 13546 2019-11-01         england     Friday         248515  E92000001
# 13547 2019-12-01         england     Sunday         250410  E92000001
# 13548 2020-01-01         england  Wednesday         247355  E92000001
#
#        houses_sold  no_of_crimes  day  month  year
# 0             17.0           NaN    1      1  1995
# ...

# %% [markdown]
# ### 4) Remove the columns "year" and "month" from dataframe.

# %%
data.head(2)
# Out:
#         date            area   day_name  average_price       code  \
# 0 1995-01-01  city of london     Sunday          91449  E09000001
# 1 1995-02-01  city of london  Wednesday          82203  E09000001
#
#    houses_sold  no_of_crimes  day  month  year
# 0         17.0           NaN    1      1  1995
# 1          7.0           NaN    1      2  1995

# %%
data.drop(["month" , "year"] , axis = 1)
# Out:
#             date            area   day_name  average_price       code  \
# 0     1995-01-01  city of london     Sunday          91449  E09000001
# 1     1995-02-01  city of london  Wednesday          82203  E09000001
# 2     1995-03-01  city of london  Wednesday          79121  E09000001
# 3     1995-04-01  city of london   Saturday          77101  E09000001
# 4     1995-05-01  city of london     Monday          84409  E09000001
# ...          ...             ...        ...            ...        ...
# 13544 2019-09-01         england     Sunday         249942  E92000001
# 13545 2019-10-01         england    Tuesday         249376  E92000001
# 13546 2019-11-01         england     Friday         248515  E92000001
# 13547 2019-12-01         england     Sunday         250410  E92000001
# 13548 2020-01-01         england  Wednesday         247355  E92000001
#
#        houses_sold  no_of_crimes  day
# 0             17.0           NaN    1
# 1              7.0           NaN    1
# ...

# %% [markdown]
# ### 5) Show all the records where "No. of crimes" is 0 and how many such records are there ?

# %%
data.head(2)
# Out:
#         date            area   day_name  average_price       code  \
# 0 1995-01-01  city of london     Sunday          91449  E09000001
# 1 1995-02-01  city of london  Wednesday          82203  E09000001
#
#    houses_sold  no_of_crimes  day  month  year
# 0         17.0           NaN    1      1  1995
# 1          7.0           NaN    1      2  1995

# %%
data [data["no_of_crimes"] == 0]
# Out:
#           date            area  day_name  average_price       code  \
# 72  2001-01-01  city of london    Monday         284262  E09000001
# 73  2001-02-01  city of london  Thursday         198137  E09000001
# 74  2001-03-01  city of london  Thursday         189033  E09000001
# 75  2001-04-01  city of london    Sunday         205494  E09000001
# 76  2001-05-01  city of london   Tuesday         223459  E09000001
# ..         ...             ...       ...            ...        ...
# 178 2009-11-01  city of london    Sunday         397909  E09000001
# 179 2009-12-01  city of london   Tuesday         411955  E09000001
# 180 2010-01-01  city of london    Friday         464436  E09000001
# 181 2010-02-01  city of london    Monday         490525  E09000001
# 182 2010-03-01  city of london    Monday         498241  E09000001
#
#      houses_sold  no_of_crimes  day  month  year
# 72          24.0           0.0    1      1  2001
# 73          37.0           0.0    1      2  2001
# ...

# %%
len(data [data["no_of_crimes"] == 0])
# Out:
# 104

# %% [markdown]
# ### 6) What is minimum and maximum "average_price" per year in England?

# %%
data.head(2)
# Out:
#         date            area   day_name  average_price       code  \
# 0 1995-01-01  city of london     Sunday          91449  E09000001
# 1 1995-02-01  city of london  Wednesday          82203  E09000001
#
#    houses_sold  no_of_crimes  day  month  year
# 0         17.0           NaN    1      1  1995
# 1          7.0           NaN    1      2  1995

# %%
data["area"].unique()
# Out:
# array(['city of london', 'barking and dagenham', 'barnet', 'bexley',
#        'brent', 'bromley', 'camden', 'croydon', 'ealing', 'enfield',
#        'tower hamlets', 'greenwich', 'hackney', 'south east',
#        'hammersmith and fulham', 'haringey', 'harrow', 'havering',
#        'hillingdon', 'hounslow', 'islington', 'kensington and chelsea',
#        'kingston upon thames', 'lambeth', 'lewisham', 'merton', 'newham',
#        'redbridge', 'richmond upon thames', 'southwark', 'sutton',
#        'waltham forest', 'wandsworth', 'westminster', 'inner london',
#        'outer london', 'north east', 'north west', 'yorks and the humber',
#        'east midlands', 'west midlands', 'east of england', 'london',
#        'south west', 'england'], dtype=object)

# %%
df = data[data["area"] == "england"]

df
# Out:
#             date     area   day_name  average_price       code  houses_sold  \
# 13248 1995-01-01  england     Sunday          53203  E92000001      47639.0
# 13249 1995-02-01  england  Wednesday          53096  E92000001      47880.0
# 13250 1995-03-01  england  Wednesday          53201  E92000001      67025.0
# 13251 1995-04-01  england   Saturday          53591  E92000001      56925.0
# 13252 1995-05-01  england     Monday          53678  E92000001      64192.0
# ...          ...      ...        ...            ...        ...          ...
# 13544 2019-09-01  england     Sunday         249942  E92000001      64605.0
# 13545 2019-10-01  england    Tuesday         249376  E92000001      68677.0
# 13546 2019-11-01  england     Friday         248515  E92000001      67814.0
# 13547 2019-12-01  england     Sunday         250410  E92000001          NaN
# 13548 2020-01-01  england  Wednesday         247355  E92000001          NaN
#
#        no_of_crimes  day  month  year
# ...

# %%
df.groupby("year")["average_price"].min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
df.groupby("year")["average_price"].max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# ### 7) What is maximum and minimum no. of crimes recorded per area ?

# %%
data.head(2)
# Out:
#         date            area   day_name  average_price       code  \
# 0 1995-01-01  city of london     Sunday          91449  E09000001
# 1 1995-02-01  city of london  Wednesday          82203  E09000001
#
#    houses_sold  no_of_crimes  day  month  year
# 0         17.0           NaN    1      1  1995
# 1          7.0           NaN    1      2  1995

# %%
data.groupby("area")["no_of_crimes"].min().sort_values()
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %%
data.groupby("area")["no_of_crimes"].max().sort_values(ascending = False)
# Out:
# area
# westminster               7461.0
# lambeth                   4701.0
# camden                    4558.0
# southwark                 3821.0
# newham                    3668.0
# hackney                   3466.0
# ealing                    3401.0
# islington                 3384.0
# tower hamlets             3316.0
# croydon                   3263.0
# haringey                  3199.0
# wandsworth                3051.0
# waltham forest            2941.0
# brent                     2937.0
# barnet                    2893.0
# greenwich                 2853.0
# hillingdon                2819.0
# hounslow                  2817.0
# lewisham                  2813.0
# enfield                   2798.0
# kensington and chelsea    2778.0
# hammersmith and fulham    2645.0
# bromley                   2637.0
# redbridge                 2560.0
# barking and dagenham      2049.0
# havering                  1956.0
# bexley                    1914.0
# harrow                    1763.0
# ...

# %% [markdown]
# ### 8) Show the total count of records of each area, where average price is less than 100000.

# %%
data.head(2)
# Out:
#         date            area   day_name  average_price       code  \
# 0 1995-01-01  city of london     Sunday          91449  E09000001
# 1 1995-02-01  city of london  Wednesday          82203  E09000001
#
#    houses_sold  no_of_crimes  day  month  year
# 0         17.0           NaN    1      1  1995
# 1          7.0           NaN    1      2  1995

# %%
data[data["average_price"] < 100000]
# Out:
#             date            area   day_name  average_price       code  \
# 0     1995-01-01  city of london     Sunday          91449  E09000001
# 1     1995-02-01  city of london  Wednesday          82203  E09000001
# 2     1995-03-01  city of london  Wednesday          79121  E09000001
# 3     1995-04-01  city of london   Saturday          77101  E09000001
# 4     1995-05-01  city of london     Monday          84409  E09000001
# ...          ...             ...        ...            ...        ...
# 13330 2001-11-01         england   Thursday          95083  E92000001
# 13331 2001-12-01         england   Saturday          95992  E92000001
# 13332 2002-01-01         england    Tuesday          96215  E92000001
# 13333 2002-02-01         england     Friday          96676  E92000001
# 13334 2002-03-01         england     Friday          98962  E92000001
#
#        houses_sold  no_of_crimes  day  month  year
# 0             17.0           NaN    1      1  1995
# ...

# %%
data[data["average_price"] < 100000]["area"]
# Out:
# 0        city of london
# 1        city of london
# 2        city of london
# 3        city of london
# 4        city of london
#               ...
# 13330           england
# 13331           england
# 13332           england
# 13333           england
# 13334           england
# Name: area, Length: 2209, dtype: object

# %%
data[data["average_price"] < 100000]["area"].value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...

# %% [markdown]
# # Netflix Data Analysis :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\All Csv's\Netflix.csv")

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.tail(2)
# Out:
#      Show_Id Category                                    Title  Director  \
# 7787   s7786  TV Show                    Zumbo's Just Desserts       NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn
#
#                             Cast                                Country  \
# 7787  Adriano Zumbo, Rachel Khoo                              Australia
# 7788                         NaN  United Kingdom, Canada, United States
#
#           Release_Date Rating  Duration                                Type  \
# 7787  October 31, 2020  TV-PG  1 Season  International TV Shows, Reality TV
# 7788     March 1, 2020  TV-MA    90 min     Documentaries, Music & Musicals
#
#                                             Description
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7789, step=1)

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.count()
# Out:
# Show_Id         7789
# Category        7789
# Title           7789
# Director        5401
# Cast            7071
# Country         7282
# Release_Date    7779
# Rating          7782
# Duration        7789
# Type            7789
# Description     7789
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.nunique()
# Out:
# Show_Id         7787
# Category           2
# Title           7787
# Director        4050
# Cast            6831
# Country          681
# Release_Date    1565
# Rating            14
# Duration         216
# Type             492
# Description     7769
# dtype: int64

# %%
data.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isna())
py.show()

# %% [markdown]
# ### 1) Is there any duplicate values in dataset? If yes, remove duplicates?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
## Check duplicates


data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
## Drop duplicated 

data.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.drop_duplicates(inplace = True)
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## 2) For "House of cards" what is the show id and who is Director of show?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data[data["Title"] == "House of Cards"]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data [data["Title"].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data [data["Title"].str.contains("House of Cards")]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## 3) In which year highest number of Tv shows and Movies were released? Show with bar graph

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data["Date_New"] = pd.to_datetime(data["Release_Date"])
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_New        datetime64[ns]
# dtype: object

# %%
data["Year"] = data["Date_New"].dt.year
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data["Year"].value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %%
py.figure(figsize = (10,4))
data["Year"].value_counts().plot(kind = "bar" , color = "orange" , edgecolor = "black")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4) How many movies and Tv shows in this dataset? Show with the bar graph.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data.groupby("Category").count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5377   5377      5214  4951     5147          5377    5372
# TV Show      2410   2410       185  2118     2133          2400    2408
#
#           Duration  Type  Description  Date_New  Year
# Category
# Movie         5377  5377         5377      5377  5377
# TV Show       2410  2410         2410      2400  2400

# %%
data.groupby("Category")["Category"].count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(data["Category"], palette = "mako")
py.show()

# %% [markdown]
# ## 5) Show all the movies that released in the year 2000.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[ (data["Category"] == "Movie") & (data["Year"] == 2000) ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_New, Year]
# Index: []

# %%
data[ (data["Category"] == "Movie") & (data["Year"] == 2020) ]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# ## 6) Show only the Titles of all the TV shows that were released in India only.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data [ (data["Category"] == "TV Show") & (data["Country"] == "India")]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country  \
# ...

# %%
data [ (data["Category"] == "TV Show") & (data["Country"] == "India")] ["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ## 7) Show Top 10 Directors who gave highest number of TV shows and Movies to Netflix.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data["Director"].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ## 8) Show all the records where "category" is "movie" and "Type" is "Comedies" or "Country" is "United Kingdom".

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data [ (data["Category"] == "Movie") & (data["Type"] == "Comedies") | (data["Country"] == "UNited Kingdom")]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %% [markdown]
# ## 9) In how many movies/shows "TomCruise" were cast ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[data["Cast"] == "TomCruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_New, Year]
# Index: []

# %%
data[data["Cast"].str.contains("Tom Cruise")]

## dataframe has null values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6108\1785629362.py in <module>
# ----> 1 data[data["Cast"].str.contains("Tom Cruise")]
#       2
#       3 ## dataframe has null values
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
# -> 3495         if com.is_bool_indexer(key):
#    3496             return self._getitem_bool_array(key)
#    3497
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     142                     # Don't raise on e.g. ["A", "B", np.nan], see
#     143                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 144                     raise ValueError(na_msg)
#     145                 return False
#     146             return True
#
# ...

# %%
df = data.dropna()
df
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df[df["Cast"] == "TomCruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_New, Year]
# Index: []

# %%
df.isna().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# Date_New        0
# Year            0
# dtype: int64

# %% [markdown]
# ## 10) What are the different ratings defined by Netflix?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
data["Rating"].nunique()
# Out:
# 14

# %% [markdown]
# ## 11) How many movies got "TV-14" rating in "Canada" ?

# %%
data[(data["Category"] == "Movie") & (data["Rating"] == "TV-14") & (data["Country"] == "Canada")]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
len(data[(data["Category"] == "Movie") & (data["Rating"] == "TV-14") & (data["Country"] == "Canada")])
# Out:
# 11

# %% [markdown]
# ## 12) How many TV Show got "R" rating after year 2018?

# %%
data [ (data["Category"] == "TV Show") & (data["Rating"] == "R") & (data["Year"] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description   Date_New    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ## 13) What is maximum duration of Movie/Show on Netflix?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data["Duration"].dtypes
# Out:
# dtype('O')

# %%
data['Duration'].value_counts()
# Out:
# 1 Season     1608
# 2 Seasons     382
# 3 Seasons     184
# 90 min        136
# 93 min        131
#              ...
# 182 min         1
# 224 min         1
# 233 min         1
# 196 min         1
# 191 min         1
# Name: Duration, Length: 216, dtype: int64

# %%
data.groupby("Category")["Duration"].min()
# Out:
# Category
# Movie        10 min
# TV Show    1 Season
# Name: Duration, dtype: object

# %%
data.groupby("Category")["Duration"].max()
# Out:
# Category
# Movie         99 min
# TV Show    9 Seasons
# Name: Duration, dtype: object

# %%
data[["Minute" , "Unit"]] = data["Duration"].str.split(" " , expand = True)

data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data["Minute"].min()
# Out:
# '1'

# %%
data["Minute"].max()
# Out:
# '99'

# %% [markdown]
# ## 14) Which individual country has the highest no. of TV Shows?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
df_tv_show = data[data["Category"] == "TV Show"]

df_tv_show
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df_tv_show["Country"].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# ## 15) Find all the instances where :
# Category is "Movie" and Type is "Dramas"
#
# or
#
# Category is "TV Show" and Type is "Kids' TV"

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   Date_New    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
data [ ((data["Category"] == "Movie") & (data['Type'] == "Dramas")) | ( (data["Category"] == "TV Show") & (data["Type"] == "Kids TV"))]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
len(data [ ((data["Category"] == "Movie") & (data['Type'] == "Dramas")) | ( (data["Category"] == "TV Show") & (data["Type"] == "Kids TV"))])
# Out:
# 117

# %% [markdown]
# # Udemy Data Analysis :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\All Csv's\udemy.csv")

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.tail(2)
# Out:
#       course_id                                       course_title  is_paid  \
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures       level  \
# 3680  Free              229            0            33  All Levels
# 3681    50               12            1            15  All Levels
#
#      content_duration   published_timestamp           subject
# 3680          2 hours  2017-05-26T16:45:55Z  Business Finance
# 3681        1.5 hours  2016-09-26T22:19:48Z    Graphic Design

# %%
data.shape
# Out:
# (3682, 11)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=3682, step=1)

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data.count()
# Out:
# course_id              3682
# course_title           3682
# is_paid                3682
# price                  3682
# num_subscribers        3682
# num_reviews            3682
# num_lectures           3682
# level                  3682
# content_duration       3682
# published_timestamp    3682
# subject                3682
# dtype: int64

# %%
data.nunique()
# Out:
# course_id              3676
# course_title           3667
# is_paid                   2
# price                    38
# num_subscribers        2198
# num_reviews             511
# num_lectures            229
# level                     4
# content_duration        109
# published_timestamp    3676
# subject                   4
# dtype: int64

# %%
data.isna().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
data.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.682000e+03      3682.000000   3682.000000   3682.000000
# mean   6.766121e+05      3194.230310    156.093156     40.065182
# std    3.436355e+05      9499.378361    934.957204     50.373299
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.078430e+05       110.250000      4.000000     15.000000
# 50%    6.885580e+05       911.500000     18.000000     25.000000
# 75%    9.617515e+05      2540.250000     67.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %% [markdown]
# ### 1) What are the different subjects for which Udemy is offering courses?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data["subject"].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data["subject"].nunique()
# Out:
# 4

# %% [markdown]
# ### 2) Which subject has the maximum number of courses?

# %%
data["subject"].value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# ### 3) Show all the courses which are free of cost?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data[data["price"] == "Free"]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
len(data[data["price"] == "Free"])
# Out:
# 310

# %% [markdown]
# ### 4) Show all the courses which are paid?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data[data["is_paid"] == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
len(data[data["is_paid"] == True])
# Out:
# 3372

# %% [markdown]
# ### 5) Which are the top selling courses?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.sort_values(by = "num_subscribers" , ascending=False).head(5)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 2230  Free           268923         8629            45      All Levels
# 776   Free           161029          279            27  Beginner Level
# 3385   200           121584        27445           342      All Levels
# 640   Free           120291         5924            30  Beginner Level
# 3316   200           114512        22412           304      All Levels
#
#      content_duration   published_timestamp          subject
# ...

# %% [markdown]
# ### 6) Which are the least selling courses?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.sort_values(by = "num_subscribers", ascending = False ).tail(5)
# Out:
#       course_id                                       course_title  is_paid  \
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...     True
# 1267    1258666                Financial Statement Auditing Cycles     True
# 2070    1215926                Kickstarter success in 5 easy steps     True
# 1931    1247992  Introduction to Project Management for Finance...     True
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...     True
#
#      price  num_subscribers  num_reviews  num_lectures               level  \
# 2290    20                0            0             6          All Levels
# 1267    50                0            0             9  Intermediate Level
# 2070    20                0            0            12          All Levels
# 1931    50                0            0             9      Beginner Level
# 3165    20                0            0             7      Beginner Level
#
# ...

# %% [markdown]
# ### 7) Show all the courses of Graphic Design where price below 100.

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data["subject"].unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data[(data["subject"] == "Graphic Design") & (data["price"] < "100")]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
data[(data["subject"] == "Graphic Design") & (data["price"] == "100")]
# Out:
#       course_id                                       course_title  is_paid  \
# 47      1269190          7 Secrets To Designing In Black and White     True
# 169      983444       Adobe Illustrator Vectors For Hand Letterers     True
# 184      638040  Adobe Photoshop Essentials: Master Adobe Photo...     True
# 520      978462              Blender Modelling Series - Volume Two     True
# 699      757900                          Canva : Book Cover Design     True
# 1029    1160004                 Design a logo for FREE in Inkscape     True
# 1071    1161864  Diseño impreso - Preimpresión para offset en I...     True
# 1444     490392                Getting Started with Illustrator CC     True
# 1568     727510             How To Become An Etsy Wholesale Seller     True
# 1616     996868          How to Design a Logo in Adobe Illustrator     True
# 1697     654038              How To Sell Your Art Online With ETSY     True
# ...

# %% [markdown]
# ### 8) List out all the courses that are related to Python.

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data[data["course_title"].str.contains("Python")]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
len(data["course_title"].str.contains("Python"))
# Out:
# 3682

# %% [markdown]
# ### 9) What are the courses that published in 2015?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data["published_timestamp"] = pd.to_datetime(data["published_timestamp"])

data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data["year"] = data["published_timestamp"].dt.year

data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments  2017

# %%
data[data["year"] == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
len(data[data["year"] == 2015])
# Out:
# 1014

# %% [markdown]
# ### 10) What are the maximum number of subscribers for each level of courses?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments  2017

# %%
data.groupby("level")["num_subscribers"].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.groupby("level")["num_subscribers"].min()
# Out:
# level
# All Levels            0
# Beginner Level        0
# Expert Level          1
# Intermediate Level    0
# Name: num_subscribers, dtype: int64

# %%
data.groupby("level")["num_subscribers"].sum()
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
data.groupby("level").sum()
# Out:
#                      course_id  is_paid  num_subscribers  num_reviews  \
# level
# All Levels          1256830046     1810          6916112       404300
# Beginner Level       889276519     1113          4052843       129086
# Expert Level          40926744       58            50196         2333
# Intermediate Level   304252466      391           742005        39016
#
#                     num_lectures     year
# level
# All Levels                 88698  3893624
# Beginner Level             41908  2561736
# Expert Level                1785   116897
# Intermediate Level         15129   848567

# %%
data.groupby("level").min()
# Out:
#                     course_id  \
# level
# All Levels               8324
# Beginner Level          12975
# Expert Level            42640
# Intermediate Level      17887
#
#                                                          course_title  \
# level
# All Levels          #1 Piano Hand Coordination: Play 10th Ballad i...
# Beginner Level      1 - Concepts of Statistics For Beginners Step ...
# Expert Level                               Adobe InDesign CC Advanced
# Intermediate Level  #10 Hand Coordination - Transfer Chord Ballad ...
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels            False   100                0            0             0
# Beginner Level        False   100                0            0             0
# Expert Level           True   100                1            0             6
# Intermediate Level    False   100                0            0             5
#
# ...

# %%
data.groupby("level").max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels             True  Free           268923        27445           544
# Beginner Level         True  Free           161029         5924           779
# Expert Level           True    95             5172          249           157
# Intermediate Level     True  Free            29167         3326           320
#
# ...

# %% [markdown]
# # Weather Data Analysis :

# %%
data = pd.read_csv(r"E:\c drive\Desktop\CloudyML\New CloudyML\Python\Python Data Analysis Projects\Weather data Analysis\Weather Data.csv")

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.tail(2)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ## 1) Find all the unique "Wind speed" values in data?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
data["Wind Speed_km/h"].nunique()
# Out:
# 34

# %% [markdown]
# ## 2) Find the number of times when the "Weather is exactly clear"?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data["Weather"].value_counts()["Clear"]
# Out:
# 1326

# %%
data[data["Weather"] == "Clear"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby("Weather").get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ## 3) Find the no. of times when the "Wind speed was exactly 4km/hr"?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data[data["Wind Speed_km/h"] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
data["Wind Speed_km/h"].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: Wind Speed_km/h, dtype: int64

# %%
data["Wind Speed_km/h"].value_counts()[4]
# Out:
# 474

# %% [markdown]
# ## 4) Find out all the not_null values in the data ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.notna().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ## 5) Rename the column "Weather" to " Weather Condition"

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns = {"Weather" : "Weather Condition"})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## 6) What is the mean visibility ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data["Visibility_km"].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# ## 7) What is the standard deviation of "Pressure" in this data ?

# %%
data["Press_kPa"].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ## 8) What is variance of "Relative humudity" in this data ?

# %%
data["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# ## 9) Find all the instances when "Snow" was recorded ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data[data["Weather"] == "Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
len(data[data["Weather"] == "Snow"])
# Out:
# 390

# %%
data["Weather"].value_counts()["Snow"]
# Out:
# 390

# %%
data [data["Weather"].str.contains("Snow")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
len(data[data["Weather"].str.contains("Snow")])
# Out:
# 583

# %% [markdown]
# ## 10) Find all the instances when "Wind speed above 24" and "Visibility is 25" ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data [ (data["Wind Speed_km/h"] > 24) & (data["Visibility_km"] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# ## 11) What is the Mean value of each column against each "Weather Condition" ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.groupby("Weather").mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# ## 12) What is the Minimum and Maximum value of each column against "Weather Condition" ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.groupby("Weather").min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
data.groupby("Weather").max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %% [markdown]
# ## 13) Show all the records where "Weather Condition is Fog"?

# %%
data [data["Weather"] == "Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
len(data[data["Weather"] == "Snow"])
# Out:
# 390

# %%
data [data["Weather"].str.contains("Fog")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90               11
# 8740   12/30/2012 4:00    -9.3             -10.6         90               13
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %%
len(data[data["Weather"].str.contains("Snow")])
# Out:
# 583

# %% [markdown]
# ## 14) Find all the instances where "Weather is clear" or "Visibility is above 40" ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data[(data["Weather"] == "Clear") | (data["Visibility_km"] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# ## 15) Find all the instances when
# ### A) "Weather is Clear" and "Relative humidity is above 50"
# ## or
# ### B) "Visibility is above 40"

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data[((data["Weather"] == "Clear") & (data["Rel Hum_%"] > 50)) | (data["Visibility_km"] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
